# %%
import requests 
request_link = f"https://cdn-api.co-vin.in/api/v2/admin/location/states"
header = {'User-Agent': 'Chrome/84.0.4147.105 Safari/537.36'}
response = requests.get(request_link, headers = header)
raw_JSON = response.json()
Total_centers = len(raw_JSON['states'])


for c in range(Total_centers):
    print ()
    print (f"[{c+1}] State Name:", raw_JSON['states'][c]['state_name'],", State Id: ", raw_JSON['states'][c]['state_id'])

    print ("  -------------------------------------------------------------------------------------")
    print()
print("Enter your State Id : ")
id=input()


request_link = f"https://cdn-api.co-vin.in/api/v2/admin/location/districts/{id}"
header = {'User-Agent': 'Chrome/84.0.4147.105 Safari/537.36'}
response = requests.get(request_link, headers = header)
raw_JSON = response.json()
Total_centers = len(raw_JSON['districts'])


for c1 in range(Total_centers):
             print ()
             print (f"[{c1+1}] District Name:", raw_JSON['districts'][c1]['district_name'],", District Id: ", raw_JSON['districts'][c1]['district_id'])

             print ("  -------------------------------------------------------------------------------------")
             print()
DISTRICT=input("Enter the District Id for which you want the status => ")    
REQ_DATE = input ("Enter the Date to get status (Date format: DD-MM-YYYY) => ")
request_link = f"https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByDistrict?district_id={DISTRICT}&date={REQ_DATE}"
header = {'User-Agent': 'Chrome/84.0.4147.105 Safari/537.36'}
response = requests.get(request_link, headers = header)
raw_JSON = response.json()

Total_centers = len(raw_JSON['centers']) 
print ()
print ("                        *>>>>>>    RESULTS   <<<<<<<*                                ")
print ("-------------------------------------------------------------------------------------")
print (f"Date: {REQ_DATE} | DISTRICT CODE: {DISTRICT} ")

if Total_centers != 0:
                 print (f"Total centers in your area is: {Total_centers}" )
else:
                 print (f"Unfortunately !! Seems like no center in this area / Kindly check another district" )

print ("------------------------------------------------------------------------------------")
print ()
for cent in range(Total_centers):
    print ()
    print (f"[{cent+1}] Center Name:", raw_JSON['centers'][cent]['name'])
    print ("------------------------------------------------------------")
    print ("   Date      Vaccine Type    Minimum Age    Available ")
    print ("  ------     -------------   ------------   ----------")
    this_session = raw_JSON['centers'][cent]['sessions']
    
    for _sess in range(len(this_session)):
        print ( "{0:^12} {1:^12} {2:^14} {3:^16} ".format(this_session[_sess]['date'], this_session[_sess]['vaccine'], this_session[_sess]['min_age_limit'], this_session[_sess]['available_capacity']))
# Out:
# [1] State Name: Andaman and Nicobar Islands , State Id:  1
#   -------------------------------------------------------------------------------------
#
#
# [2] State Name: Andhra Pradesh , State Id:  2
#   -------------------------------------------------------------------------------------
#
#
# [3] State Name: Arunachal Pradesh , State Id:  3
#   -------------------------------------------------------------------------------------
#
#
# [4] State Name: Assam , State Id:  4
#   -------------------------------------------------------------------------------------
#
#
# [5] State Name: Bihar , State Id:  5
#   -------------------------------------------------------------------------------------
#
#
# [6] State Name: Chandigarh , State Id:  6
#   -------------------------------------------------------------------------------------
#
#
# [7] State Name: Chhattisgarh , State Id:  7
#   -------------------------------------------------------------------------------------
#
#
# [8] State Name: Dadra and Nagar Haveli , State Id:  8
#   -------------------------------------------------------------------------------------
#
#
# [9] State Name: Daman and Diu , State Id:  37
#   -------------------------------------------------------------------------------------
#
#
# [10] State Name: Delhi , State Id:  9
#   -------------------------------------------------------------------------------------
#
#
# [11] State Name: Goa , State Id:  10
#   -------------------------------------------------------------------------------------
#
#
# [12] State Name: Gujarat , State Id:  11
#   -------------------------------------------------------------------------------------
#
#
# [13] State Name: Haryana , State Id:  12
#   -------------------------------------------------------------------------------------
#
#
# [14] State Name: Himachal Pradesh , State Id:  13
#   -------------------------------------------------------------------------------------
#
#
# [15] State Name: Jammu and Kashmir , State Id:  14
#   -------------------------------------------------------------------------------------
#
#
# [16] State Name: Jharkhand , State Id:  15
#   -------------------------------------------------------------------------------------
#
#
# [17] State Name: Karnataka , State Id:  16
#   -------------------------------------------------------------------------------------
#
#
# [18] State Name: Kerala , State Id:  17
#   -------------------------------------------------------------------------------------
#
#
# [19] State Name: Ladakh , State Id:  18
#   -------------------------------------------------------------------------------------
#
#
# [20] State Name: Lakshadweep , State Id:  19
#   -------------------------------------------------------------------------------------
#
#
# [21] State Name: Madhya Pradesh , State Id:  20
#   -------------------------------------------------------------------------------------
#
#
# [22] State Name: Maharashtra , State Id:  21
#   -------------------------------------------------------------------------------------
#
#
# [23] State Name: Manipur , State Id:  22
#   -------------------------------------------------------------------------------------
#
#
# [24] State Name: Meghalaya , State Id:  23
#   -------------------------------------------------------------------------------------
#
#
# [25] State Name: Mizoram , State Id:  24
#   -------------------------------------------------------------------------------------
#
#
# [26] State Name: Nagaland , State Id:  25
#   -------------------------------------------------------------------------------------
#
#
# [27] State Name: Odisha , State Id:  26
#   -------------------------------------------------------------------------------------
#
#
# [28] State Name: Puducherry , State Id:  27
#   -------------------------------------------------------------------------------------
#
#
# [29] State Name: Punjab , State Id:  28
#   -------------------------------------------------------------------------------------
#
#
# [30] State Name: Rajasthan , State Id:  29
#   -------------------------------------------------------------------------------------
#
#
# [31] State Name: Sikkim , State Id:  30
#   -------------------------------------------------------------------------------------
#
#
# [32] State Name: Tamil Nadu , State Id:  31
#   -------------------------------------------------------------------------------------
#
#
# [33] State Name: Telangana , State Id:  32
#   -------------------------------------------------------------------------------------
#
#
# [34] State Name: Tripura , State Id:  33
#   -------------------------------------------------------------------------------------
#
#
# [35] State Name: Uttar Pradesh , State Id:  34
#   -------------------------------------------------------------------------------------
#
#
# [36] State Name: Uttarakhand , State Id:  35
#   -------------------------------------------------------------------------------------
#
#
# [37] State Name: West Bengal , State Id:  36
#   -------------------------------------------------------------------------------------
#
# Enter your State Id :
# 36
#
# [1] District Name: Alipurduar District , District Id:  710
#   -------------------------------------------------------------------------------------
#
#
# [2] District Name: Bankura , District Id:  711
#   -------------------------------------------------------------------------------------
#
#
# [3] District Name: Basirhat HD (North 24 Parganas) , District Id:  712
#   -------------------------------------------------------------------------------------
#
#
# [4] District Name: Birbhum , District Id:  713
#   -------------------------------------------------------------------------------------
#
#
# [5] District Name: Bishnupur HD (Bankura) , District Id:  714
#   -------------------------------------------------------------------------------------
#
#
# [6] District Name: Cooch Behar , District Id:  715
#   -------------------------------------------------------------------------------------
#
#
# [7] District Name: COOCHBEHAR , District Id:  783
#   -------------------------------------------------------------------------------------
#
#
# [8] District Name: Dakshin Dinajpur , District Id:  716
#   -------------------------------------------------------------------------------------
#
#
# [9] District Name: Darjeeling , District Id:  717
#   -------------------------------------------------------------------------------------
#
#
# [10] District Name: Diamond Harbor HD (S 24 Parganas) , District Id:  718
#   -------------------------------------------------------------------------------------
#
#
# [11] District Name: East Bardhaman , District Id:  719
#   -------------------------------------------------------------------------------------
#
#
# [12] District Name: Hoogly , District Id:  720
#   -------------------------------------------------------------------------------------
#
#
# [13] District Name: Howrah , District Id:  721
#   -------------------------------------------------------------------------------------
#
#
# [14] District Name: Jalpaiguri , District Id:  722
#   -------------------------------------------------------------------------------------
#
#
# [15] District Name: Jhargram , District Id:  723
#   -------------------------------------------------------------------------------------
#
#
# [16] District Name: Kalimpong , District Id:  724
#   -------------------------------------------------------------------------------------
#
#
# [17] District Name: Kolkata , District Id:  725
#   -------------------------------------------------------------------------------------
#
#
# [18] District Name: Malda , District Id:  726
#   -------------------------------------------------------------------------------------
#
#
# [19] District Name: Murshidabad , District Id:  727
#   -------------------------------------------------------------------------------------
#
#
# [20] District Name: Nadia , District Id:  728
#   -------------------------------------------------------------------------------------
#
#
# [21] District Name: Nandigram HD (East Medinipore) , District Id:  729
#   -------------------------------------------------------------------------------------
#
#
# [22] District Name: North 24 Parganas , District Id:  730
#   -------------------------------------------------------------------------------------
#
#
# [23] District Name: Paschim Medinipore , District Id:  731
#   -------------------------------------------------------------------------------------
#
#
# [24] District Name: Purba Medinipore , District Id:  732
#   -------------------------------------------------------------------------------------
#
#
# [25] District Name: Purulia , District Id:  733
#   -------------------------------------------------------------------------------------
#
#
# [26] District Name: Rampurhat HD (Birbhum) , District Id:  734
#   -------------------------------------------------------------------------------------
#
#
# [27] District Name: South 24 Parganas , District Id:  735
#   -------------------------------------------------------------------------------------
#
#
# [28] District Name: Uttar Dinajpur , District Id:  736
#   -------------------------------------------------------------------------------------
#
#
# [29] District Name: West Bardhaman , District Id:  737
#   -------------------------------------------------------------------------------------
# Enter the District Id for which you want the status => 735
# Enter the Date to get status (Date format: DD-MM-YYYY) => 04-11-2021
#
#                         *>>>>>>    RESULTS   <<<<<<<*
# -------------------------------------------------------------------------------------
# Date: 04-11-2021 | DISTRICT CODE: 735
# Total centers in your area is: 2
# ------------------------------------------------------------------------------------
#
#
# [1] Center Name: Remedy Hospital Pvt S24Pgns
# ------------------------------------------------------------
#    Date      Vaccine Type    Minimum Age    Available
#   ------     -------------   ------------   ----------
#  04-11-2021   COVISHIELD        18             191
#  05-11-2021   COVISHIELD        18             193
#  06-11-2021   COVISHIELD        18             180
#  07-11-2021   COVISHIELD        18             184
#  08-11-2021   COVISHIELD        18             182
#  09-11-2021   COVISHIELD        18             198
#  10-11-2021   COVISHIELD        18             194
#
# [2] Center Name: Welkin Medicare Pvt CVC S24Pgn
# ------------------------------------------------------------
#    Date      Vaccine Type    Minimum Age    Available
#   ------     -------------   ------------   ----------
#  04-11-2021   COVISHIELD        18             246
#  05-11-2021   COVISHIELD        18             247
#  06-11-2021   COVISHIELD        18             243
#  07-11-2021   COVISHIELD        18             247
#  08-11-2021   COVISHIELD        18             249
#  09-11-2021   COVISHIELD        18             250
#  10-11-2021   COVISHIELD        18             250

# %%
import requests #can be installed using:  pip install requests

PINCODE = "0"
while len(PINCODE) != 6:
    PINCODE = input("Enter the pincode for which you want the status => ")
    if len(PINCODE) < 6:
        print (f"{PINCODE} is shorter than the actual length")
    elif len(PINCODE) > 6:
        print (f"{PINCODE} is longer than the actual length")
    
REQ_DATE = input ("Enter the Date to get status (Date format: DD-MM-YYYY) => ")

request_link = f"https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode={PINCODE}&date={REQ_DATE}"
header = {'User-Agent': 'Chrome/84.0.4147.105 Safari/537.36'}
response = requests.get(request_link, headers = header)
raw_JSON = response.json()

Total_centers = len(raw_JSON['centers'])
print ()
print ("                        *>>>>>>    RESULTS   <<<<<<<*                                ")
print ("-------------------------------------------------------------------------------------")
print (f"Date: {REQ_DATE} | Pincode: {PINCODE} ")

if Total_centers != 0:
    print (f"Total centers in your area is: {Total_centers}" )
else:
    print (f"Unfortunately !! Seems like no center in this area / Kindly re-check the Pincode" )

print ("------------------------------------------------------------------------------------")
print ()

for cent in range(Total_centers):
    print ()
    print (f"[{cent+1}] Center Name:", raw_JSON['centers'][cent]['name'])
    print ("------------------------------------------------------------")
    print ("   Date      Vaccine Type    Minimum Age    Available ")
    print ("  ------     -------------   ------------   ----------")
    this_session = raw_JSON['centers'][cent]['sessions']
    
    for _sess in range(len(this_session)):
        print ( "{0:^12} {1:^12} {2:^14} {3:^16} ".format(this_session[_sess]['date'], this_session[_sess]['vaccine'], this_session[_sess]['min_age_limit'], this_session[_sess]['available_capacity']))
# Out:
# Enter the pincode for which you want the status => 700084
# Enter the Date to get status (Date format: DD-MM-YYYY) => 04-11-2021
#
#                         *>>>>>>    RESULTS   <<<<<<<*
# -------------------------------------------------------------------------------------
# Date: 04-11-2021 | Pincode: 700084
# Total centers in your area is: 2
# ------------------------------------------------------------------------------------
#
#
# [1] Center Name: Remedy Hospital Pvt S24Pgns
# ------------------------------------------------------------
#    Date      Vaccine Type    Minimum Age    Available
#   ------     -------------   ------------   ----------
#  04-11-2021   COVISHIELD        18             191
#  05-11-2021   COVISHIELD        18             193
#  06-11-2021   COVISHIELD        18             180
#  07-11-2021   COVISHIELD        18             184
#  08-11-2021   COVISHIELD        18             182
#  09-11-2021   COVISHIELD        18             198
#  10-11-2021   COVISHIELD        18             194
#
# [2] Center Name: Welkin Medicare Pvt CVC S24Pgn
# ------------------------------------------------------------
#    Date      Vaccine Type    Minimum Age    Available
#   ------     -------------   ------------   ----------
#  04-11-2021   COVISHIELD        18             246
#  05-11-2021   COVISHIELD        18             247
#  06-11-2021   COVISHIELD        18             243
#  07-11-2021   COVISHIELD        18             247
#  08-11-2021   COVISHIELD        18             249
#  09-11-2021   COVISHIELD        18             250
#  10-11-2021   COVISHIELD        18             250
